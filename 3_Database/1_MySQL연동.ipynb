# %% [markdown]
# # **1. mysqlclient**
# - 파이썬에서 MySQL 데이터베이스와 상호작용하기 위해 사용하는 공식 라이브러리
# - PyMySQL, mysqlclient를 가장 많이 사용함
# - 사용법은 비슷하나 mysqlclient가 속도상으로도 유리하기 때문에 권장
# - SQLAlchemy를 실무에서는 가장 많이 사용함
#
# - 설치
# ***
#     python -m pip install mysqlclient
#     Python 에서 import MySQLdb 쓰고 install 하기
# ***

# %%
import MySQLdb

# %% [markdown]
# ### 1. MySLQ 접속
# ```
# MySQLdb.connect(host='IP주소', user='사용자명', password='비밀번호', db='데이터베이스명')
# ```

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
db
# Out:
# <_mysql.connection open to 'localhost' at 000001FEF09AFAE0>

# %% [markdown]
# ### 2. cursor 생성
# - 하나의 데이터베이스 connection에 대해 독립적으로 SQL문을 실행할 수 있는 작업환경을 제공하는 객체
# - 하나의 connection에 동시에 한개의 cursor만 생성할 수 있으면, cursor를 통해 SQL문을 실행하면 실행결과를 튜플단위로 반환

# %%
cur = db.cursor()
cur.execute("select * from member")
# Out:
# 9

# %% [markdown]
# ### 3. SQL문의 결과 반환
# - fetchall(): 한 번에 모든 tuple을 가져옴. 검색 결과가 매우 많다면 메모리 오버헤드가 발생할 수 있음
# - fetchone(): 한번에 하나의 tuple을 가져옴. 다시 fetchone() 메서드를 호출하면 다음 데이터를 가져옴

# %%
# fetchall을 처음 실행하면 데이터를 다 가져오고, 한번 더 실행하면 데이터가 없음
data = cur.fetchall()
data
# Out:
# ((1,
#   'apple',
#   '1111',
#   '김사과',
#   '010-1111-1111',
#   'apple@apple.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 서초구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 54, 1),
#   150,
#   '여자'),
#  (2,
#   'banana',
#   '2222',
#   '반하나',
#   '010-2222-2222',
#   'banana@banana.com',
#   '001011',
#   '4011111',
#   '12345',
#   '서울 강남구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 54, 47),
#   250,
#   '여자'),
#  (4,
#   'melon',
#   '4444',
#   '이메론',
#   '010-4444-4444',
#   'melon@melon.com',
#   '001011',
#   '4011111',
#   '12345',
#   '경기도 고양시',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 9, 54, 50),
#   150,
#   '남자'),
#  (5,
#   'cherry',
#   '5555',
#   '채리',
#   '010-5555-5555',
#   'cherry@cherry.com',
#   '001011',
#   '4011111',
#   '12345',
#   '부산 해운대구',
#   '양재동',
#   '111-11',
#   None,
#   50,
#   '여자'),
#  (7,
#   'berry',
#   '6666',
#   '베애리',
#   '010-6666-6666',
#   'berry@berry.com',
#   '001011',
#   '4011111',
#   '12345',
#   '부산 중구',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 11, 22, 33),
#   1000,
#   '여자'),
#  (8,
#   'orange',
#   '3333',
#   '오렌지',
#   '010-3333-3333',
#   'orange@orange.com',
#   '001011',
#   '4011111',
#   '12345',
#   '경기도 성남시',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 5, 11, 9, 17),
#   1000,
#   '남자'),
#  (12,
#   'avocado',
#   '7777',
#   '아보카도',
#   '010-7777-7777',
#   'avocado@apple.com',
#   '001011',
#   '4011111',
#   '12345',
#   '경기도 화성시',
#   '양재동',
#   '111-11',
#   datetime.datetime(2026, 6, 8, 12, 27, 15),
#   1000,
#   '남자'),
#  (13,
#   'mango',
#   '8888',
#   '마앙고',
#   '010-8888-8888',
#   'mango@mango.com',
#   '000000',
#   '0000000',
#   '',
#   '',
#   None,
#   None,
#   datetime.datetime(2026, 6, 9, 10, 47, 18),
#   1000,
#   '남자'),
#  (15,
#   'peach',
#   '0000',
#   '복숭아',
#   '010-0000-0000',
#   'peach@peach.com',
#   '000000',
#   '0000000',
#   None,
#   None,
#   None,
#   None,
#   datetime.datetime(2026, 6, 9, 10, 51, 41),
#   1000,
#   '남자'))

# %%
cur.execute("select userid, name, gender from member")
# Out:
# 9

# %%
row = cur.fetchone()
row
# Out:
# ('apple', '김사과', '여자')

# %%
row = cur.fetchone()
row
# Out:
# ('banana', '반하나', '여자')

# %%
sql = "select userid, name, gender, hp from member"
cur.execute(sql)
# Out:
# 9

# %%
while True:
    row = cur.fetchone()
    if row:
        print(row)
    else:
        break
# Out:
# ('apple', '김사과', '여자', '010-1111-1111')
# ('banana', '반하나', '여자', '010-2222-2222')
# ('melon', '이메론', '남자', '010-4444-4444')
# ('cherry', '채리', '여자', '010-5555-5555')
# ('berry', '베애리', '여자', '010-6666-6666')
# ('orange', '오렌지', '남자', '010-3333-3333')
# ('avocado', '아보카도', '남자', '010-7777-7777')
# ('mango', '마앙고', '남자', '010-8888-8888')
# ('peach', '복숭아', '남자', '010-0000-0000')

# %% [markdown]
# ### 4. 딕셔너리 형태로 결과 반환
# ```
# cursor(MySLQdb.cursors.DictCursor)
# ```

# %%
cur = db.cursor(MySQLdb.cursors.DictCursor)
cur.execute(sql)

result = cur.fetchall()
result
# Out:
# ({'userid': 'apple', 'name': '김사과', 'gender': '여자', 'hp': '010-1111-1111'},
#  {'userid': 'banana', 'name': '반하나', 'gender': '여자', 'hp': '010-2222-2222'},
#  {'userid': 'melon', 'name': '이메론', 'gender': '남자', 'hp': '010-4444-4444'},
#  {'userid': 'cherry', 'name': '채리', 'gender': '여자', 'hp': '010-5555-5555'},
#  {'userid': 'berry', 'name': '베애리', 'gender': '여자', 'hp': '010-6666-6666'},
#  {'userid': 'orange', 'name': '오렌지', 'gender': '남자', 'hp': '010-3333-3333'},
#  {'userid': 'avocado', 'name': '아보카도', 'gender': '남자', 'hp': '010-7777-7777'},
#  {'userid': 'mango', 'name': '마앙고', 'gender': '남자', 'hp': '010-8888-8888'},
#  {'userid': 'peach', 'name': '복숭아', 'gender': '남자', 'hp': '010-0000-0000'})

# %%
cur.execute(sql)

while True:
    row = cur.fetchone()
    if row:
        print(f"아이디:{row['userid']}, 이름:{row['name']}, 성별:{row['gender']}, 전화번호:{row['hp']}")
    else : 
        break
# Out:
# 아이디:apple, 이름:김사과, 성별:여자, 전화번호:010-1111-1111
# 아이디:banana, 이름:반하나, 성별:여자, 전화번호:010-2222-2222
# 아이디:melon, 이름:이메론, 성별:남자, 전화번호:010-4444-4444
# 아이디:cherry, 이름:채리, 성별:여자, 전화번호:010-5555-5555
# 아이디:berry, 이름:베애리, 성별:여자, 전화번호:010-6666-6666
# 아이디:orange, 이름:오렌지, 성별:남자, 전화번호:010-3333-3333
# 아이디:avocado, 이름:아보카도, 성별:남자, 전화번호:010-7777-7777
# 아이디:mango, 이름:마앙고, 성별:남자, 전화번호:010-8888-8888
# 아이디:peach, 이름:복숭아, 성별:남자, 전화번호:010-0000-0000

# %% [markdown]
# ### 5. Cursor와 Connection 닫기
#  - 메모리 아껴 쓰기
#  - 사용 후에 둘다 끊어 주어야 함
# ```
# cur.close()
# db.close()
# ```

# %% [markdown]
# # **2. 데이터 삽입하기**

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

# %%
sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"

data = ("mango", "8888", "마앙고", "010-8888-8888", "mango@mango.com", "남자", "000000", "0000000")

cur.execute(sql, data)
db.commit() # 반영하기.
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[17], line 5
#       1 sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"
#       2
#       3 data = ("mango", "8888", "마앙고", "010-8888-8888", "mango@mango.com", "남자", "000000", "0000000")
#       4
# ----> 5 cur.execute(sql, data)
#       6 db.commit() # 반영하기.
#
# File c:\wooki\3_Database\venv\Lib\site-packages\MySQLdb\cursors.py:179, in BaseCursor.execute(self, query, args)
#     176 mogrified_query = self._mogrify(query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File c:\wooki\3_Database\venv\Lib\site-packages\MySQLdb\cursors.py:330, in BaseCursor._query(self, q)
#     328 self.rowcount = None
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#     332 self._post_get_result()
#
# File c:\wooki\3_Database\venv\Lib\site-packages\MySQLdb\connections.py:286, in Connection.query(self, query)
#     284 if isinstance(query, bytearray):
#     285     query = bytes(query)
# --> 286 _mysql.connection.query(self, query)
#
# IntegrityError: (1062, "Duplicate entry 'mango' for key 'member.userid'")

# %%
sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2) values (%s, %s, %s, %s, %s, %s, %s, %s)"

data = [("pear", "9999", "배철수", "010-9999-9999", "pear@pear.com", "남자", "000000", "0000000"),
        ("peach", "0000", "복숭아", "010-0000-0000", "peach@peach.com", "남자", "000000", "0000000")]

cur.executemany(sql, data)
db.commit() # 반영하기.

# %%
cur.close()
db.close()

# %% [markdown]
# ### 회원가입 프로그램

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('아이디를 입력하세요: ')
        userpw = input('비밀번호를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')
        sql = "insert into member (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3) values (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        data = (userid, userpw, name, hp, email, gender, ssn1, ssn2, zipcode, address1, address2, address3)
        cur.execute(sql, data)
        db.commit()
        print('가입되었습니다!')
        yn = input('추가로 가입하시겠습니까? (y/n): ')
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break
    except Exception as e:
        print('다시 입력하세요')

cur.close()
db.close()
# Out:
# 가입되었습니다!
# 가입되었습니다!
# 가입되었습니다!
# 프로그램을 종료합니다

# %% [markdown]
# ### 로그인 프로그램

# %%
# 내가 만든거 
# 보안적으로 변수를 직접 넣어서 쓰면 안좋다.
# 쿼리에 쿼리문을 넣어서 공격할수도 있음.
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

try:
    while True:
        userid = input("아이디를 입력하세요:")
        userpw = input("비밀번호를 입력하세요:")
        sql = f"select userid, userpw from member where userid = '{userid}' and userpw = '{userpw}'"

        login = cur.execute(sql)

        if login == 0:
            print("로그인에 실패하였습니다")
            continue
        elif login == 1:
            print("로그인에 성공하였습니다")
            break

except Exception as e:
    print('오류')

cur.close()
db.close()
# Out:
# 로그인에 실패하였습니다
# 로그인에 실패하였습니다
# 로그인에 실패하였습니다
# 로그인에 실패하였습니다
# 로그인에 성공하였습니다

# %%
# 강사님이 한거
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

userid = input('아이디를 입력하세요')
userpw = input('비밀번호를 입력하세요')

sql = "select idx from member where userid=%s and userpw=%s"
data = (userid, userpw)
result = cur.execute(sql, data)

if result > 0:
    print('로그인 되었습니다')
else:
    print('아이디 또는 비밀번호를 확인하세요')

# %% [markdown]
# ### 회원정보 수정

# %%
cur.close()
db.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cur.close()
#       2 db.close()
#
# NameError: name 'cur' is not defined

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('변경할 아이디를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')

        
        sql = """
        update member set 
            userid = %s,
            name = %s,
            hp = %s,
            email = %s,
            ssn1 = %s,
            ssn2 = %s,
            zipcode = %s,
            address1 = %s,
            address2 = %s,
            address3 = %s,
            gender = %s'
            where userid = %s   
        """

        
        data = (name, hp, email, ssn1, ssn2, zipcode, address1, address2, address3, gender, userid)
        cur.execute(sql, data)
        db.commit()

        print('변경이 완료 되었습니다.')
        yn = input('추가로 변경하시겠습니까? (y/n): ')
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break
    except Exception as e:
        print("다시 입력하세요")

cur.close()
db.close()
# Out:
# 다시 입력하세요

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

while True:
    try:
        userid = input('변경할 아이디를 입력하세요: ')
        name = input('이름을 입력하세요: ')
        hp = input('전화번호를 입력하세요: ')
        email = input('이메일을 입력하세요: ')
        ssn1 = input('주민등록번호 앞자리를 입력하세요: ')
        ssn2 = input('주민등록번호 뒷자리를 입력하세요: ')
        zipcode = input('우편번호를 입력하세요: ')
        address1 = input('주소를 입력하세요: ')
        address2 = input('상세주소를 입력하세요: ')
        address3 = input('참고사항 입력하세요: ')
        gender = input('성별을 입력하세요(남자 또는 여자): ')
        sql = "update member set name=%s, hp=%s, email=%s, ssn1=%s, ssn2=%s, zipcode=%s, address1=%s, address2=%s, address3=%s, gender=%s where userid=%s"
        data = (name, hp, email, ssn1, ssn2, zipcode, address1, address2, address3, gender, userid)
        result = cur.execute(sql, data)
        db.commit()

        if result > 0:
            print('변경되었습니다')
        else:
            print('에러!')

        yn = input('추가로 변경하겠습니까? (y/n): ')
        if yn.lower() == 'n':
            print('프로그램을 종료합니다')
            break

    except Exception as e:
        print('다시 입력하세요')


cur.close()
db.close()
# Out:
# 변경되었습니다
# 프로그램을 종료합니다

# %% [markdown]
# ### 회원탈퇴

# %%
import MySQLdb

# %%
# 내가 만든거 
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

try:
    userid = input('탈퇴할 아이디를 입력하세요: ')
    userpw = input('탈퇴할 비밀번호를 입력하세요: ')

    sql = "delete from member where userid =%s and userpw =%s "
    data = (userid, userpw)
    result = cur.execute(sql, data)
    db.commit()

    if result > 0:
        print('탈퇴 되었습니다')
    else:
        print('아이디 또는 비밀번호가 틀렸습니다 확인해주세요')

    

except Exception as e:
    print('다시 입력하세요')


cur.close()
db.close()
# Out:
# 다시 입력하세요

# %%
#강사님 만든거
db = MySQLdb.connect(host='localhost', user='root', password='1234', db='ai')
cur = db.cursor()

userid = input('탈퇴할 아이디를 입력하세요: ')
sql = 'delete from member where userid=%s'
result = cur.execute(sql, (userid,))
db.commit()

if result > 0:
    print('탈퇴되었습니다')
else:
    print('오류')

cur.close()
db.close()
# Out:
# 탈퇴되었습니다
